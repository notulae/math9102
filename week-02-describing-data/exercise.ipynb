# %% [markdown]
# # Week 2 exercise — Describing data properly
#
# `experim` is a manufactured dataset from Pallant's *SPSS Survival Manual*. It
# describes a fictitious study of two interventions intended to help students cope
# with anxiety about a forthcoming statistics course.
#
# Students were split into two groups. One received sessions on mathematical
# skills; the other a programme designed to build confidence. All of them
# completed a Fear of Statistics test, a Confidence in Coping scale and a
# Depression scale **before** the programme (time 1), **after** it (time 2), and
# again three months later (time 3). Their exam mark was also recorded.

# %%
import math9102 as m9
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats

m9.use_house_style()

experim = m9.load_experim()

# %% [markdown]
# ---
#
# ## Question 1 — Orient yourself

# %%
# Shape, columns, dtypes, first rows.

# %% [markdown]
# *How many students are there? What does one row represent, and what does the*
# *design of the study imply about the relationship between `fost1`, `fost2` and*
# *`fost3`?*
#
# ---
#
# ## Question 2 — Describe the sample

# %%
# The grouping and demographic variables: sex, group, age.
# Use the right summary for each.

# %% [markdown]
# *Are the two intervention groups balanced on sex and age? Say what you looked*
# *at to decide, and what you would want to know that these data cannot tell you.*
#
# ---
#
# ## Question 3 — Centre, spread and shape
#
# Do `fost1` (fear of statistics at time 1) and `exam`.

# %%
# Centre and spread for both.

# %%
# Shape: a histogram for each, and the skew and kurtosis.

# %% [markdown]
# *For each variable: is the mean or the median the better summary, and why?*
# *Point at what in the output made you say so.*
#
# ---
#
# ## Question 4 — Standardise

# %%
# Convert exam marks to z-scores.

# %% [markdown]
# *Student 4 scored 52 on the exam and 50 on fear of statistics at time 1. On*
# *which measure is that student more unusual, relative to the rest of the group?*
# *Use z-scores, and say why you cannot answer it from the raw numbers.*

# %% [markdown]
# ---
#
# ## Question 5 — Choose the right picture, four times
#
# For each of these, produce the plot **and** write one sentence saying what it
# shows.

# %%
# 5.1 The distribution of fear of statistics at time 1 and at time 2.
# Put them side by side so they can be compared.

# %%
# 5.2 Depression at time 1, compared between the two intervention groups.

# %%
# 5.3 Confidence in coping at time 1, by sex.

# %%
# 5.4 The distribution of exam marks.

# %% [markdown]
# *Three of these four are served well by this week's plots as they stand. One*
# *has a feature of the study design that changes what the best plot is. Say*
# *which, why, and what you would draw instead.*
#
# ---
#
# ## Question 6 — Look for outliers

# %%
# Apply the 1.5 x IQR fence to `age`, `exam` and `depress1`.
# How many values fall beyond it in each?

# %% [markdown]
# *One of those three flags several values and the other two flag none. Look at*
# *the values that were flagged and at the shape of that variable, and say*
# *whether "outlier" is the right word for them.*
#
# *Then: for a value you did flag, what would you actually do about it? Give a*
# *different answer for a value you believe and one you do not, and say how you*
# *would tell them apart here.*
#
# ---
#
# ## Question 7 — Did the intervention work?
#
# You have no tests yet. Describe.

# %%
# Fear of statistics at time 1 and at time 2, within each intervention group.

# %%
# A picture that lets a reader compare all four of those at once.

# %% [markdown]
# *Write three sentences for a non-statistician. Do not use the words*
# *"significant", "proves", "causes" or "shows that". Do mention the sample size.*
#
# ---
#
# ## Question 8 — Judgement
#
# No code. A colleague sends you this chart description:
#
# > "We plotted the mean fear-of-statistics score at time 2 for each group as a
# > bar chart. The maths-skills bar is taller, so that intervention is worse. We
# > set the y-axis to start at 37 so the difference would be visible."
#
# Write down **three** separate things wrong with that, and say what you would
# have drawn instead.
#
# ---
#
# ## Checklist before you finish
#
# - [ ] Every variable you described has a stated level of measurement.
# - [ ] Every continuous variable has a centre, a spread **and** a statement about
#       shape.
# - [ ] Every choice of summary statistic is justified by the shape you observed.
# - [ ] Every plot is accompanied by a sentence saying what it shows.
# - [ ] Missing data is quantified for the variables you used.
# - [ ] No number in your written answers was typed by hand.
