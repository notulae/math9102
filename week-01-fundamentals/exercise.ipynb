# %% [markdown]
# # Week 1 exercise — Describing a dataset you have not seen
#
# `msleep` records sleep behaviour for 83 mammals: how long they sleep, how much
# of that is REM, how long a sleep cycle lasts, what they eat, how much they
# weigh, and how endangered they are.
#
# Your job is to find out what is in it and describe it honestly. That is the
# whole exercise.

# %%
import math9102 as m9
import numpy as np
import pandas as pd

m9.use_house_style()

msleep = m9.load_msleep()

# %% [markdown]
# ---
#
# ## Question 1 — Get oriented
#
# Before anything else: how big is it, what is in it, and what does a row
# represent?

# %%
# Shape, column names, dtypes, and the first few rows.

# %% [markdown]
# *One sentence: what does a single row of this dataset represent?*
#
# ---
#
# ## Question 2 — Classify the variables
#
# No code for this one. For each variable, give its **level of measurement** and
# say in a few words why.
#
# | Variable | Level | Why |
# |---|---|---|
# | `name` | | |
# | `genus` | | |
# | `vore` | | |
# | `order` | | |
# | `conservation` | | |
# | `sleep_total` | | |
# | `sleep_rem` | | |
# | `sleep_cycle` | | |
# | `awake` | | |
# | `brainwt` | | |
# | `bodywt` | | |
#
# Two of these are worth arguing about. Say which you found hardest and what
# decided it for you.
#
# Then: **which of these variables would it be meaningless to take a mean of, and
# why?**
#
# ---
#
# ## Question 3 — Describe the categorical variables

# %%
# Frequency table for `vore`. Watch what happens to the missing values -
# does your table count them or not?

# %%
# Frequency table for `conservation`.

# %% [markdown]
# *How many animals have no recorded conservation status, and what does that do
# to any statement you might make about conservation status in this dataset?*

# %%
# Cross-tabulate `vore` against `conservation` as counts.

# %%
# Now as percentages within rows.

# %% [markdown]
# *Say in words what your percentage table is a percentage OF. Then say what a
# column-wise version would mean instead.*
#
# ---
#
# ## Question 4 — Describe two continuous variables
#
# Do `sleep_total` and `bodywt`. They behave very differently, and that is the
# point of the question.

# %%
# Centre: mean, median and mode for each.

# %%
# Spread: range, IQR and standard deviation for each.

# %%
# Shape: a histogram for each.

# %%
# All of it at once.

# %% [markdown]
# *For each of the two variables: which measure of centre would you report, and
# which measure of spread, and why? Your answer should be different for the two
# variables — say what in the data makes it different.*
#
# ---
#
# ## Question 5 — Count the cost of missingness

# %%
# What would a complete-case analysis of sleep_total and vore cost you?

# %%
# And a complete-case analysis of sleep_cycle, brainwt and vore?

# %% [markdown]
# *Suppose you dropped every row with a missing value anywhere in the dataset,*
# *before deciding what to analyse. How many animals would you have left, and*
# *which variable would have cost you the most? Show the working.*

# %% [markdown]
# ---
#
# ## Question 6 — Describe a group difference, without testing it
#
# We have no tests yet. You can still describe.

# %%
# Describe sleep_total split by vore.

# %% [markdown]
# *Write three sentences a non-statistician could read, describing what you see.*
# *Do not use the words "significant", "proves" or "shows that". Be careful about*
# *the group sizes.*
#
# ---
#
# ## Question 7 — Judgement
#
# No code. Someone sends you this:
#
# > "We analysed a database of mammals. The average mammal sleeps 10.4 hours a
# > night and weighs 166 kg, so the typical mammal is a large, sleepy animal."
#
# Write down **three** separate problems with that sentence, and rewrite it as it
# should have been reported. You may check anything you like against the data.
#
# ---
#
# ## Checklist before you finish
#
# - [ ] Every variable has a stated level of measurement, with a reason.
# - [ ] Every categorical summary says which way it was percentaged.
# - [ ] Every continuous variable is described with a centre, a spread and a
#       statement about shape.
# - [ ] Missingness is quantified for the variables you actually used.
# - [ ] No number in your written answers was typed by hand — generate it.
