# %% [markdown]
# # Week 3 exercise — Inspect, justify, test, report
#
# This is the first exercise that asks for a complete analysis. From here to the
# end of the module, every analysis you write has this shape.
#
# **Research question.** Is a respondent's level of optimism related to how
# satisfied they are with their life?

# %%
import math9102 as m9
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats

m9.use_house_style()

survey = m9.load_survey()

# %% [markdown]
# The variables are `toptim` (Life Orientation Test total) and `tlifesat`
# (Satisfaction With Life total).
#
# ---
#
# ## Question 1 — State the hypotheses
#
# *Write H₀ and H₁ in words, about the concepts, not the column names.*
#
# *Is this one-tailed or two-tailed? Justify the choice, and note that you must*
# *make it before looking at the data.*
#
# *State your significance level.*
#
# ---
#
# ## Question 2 — Assess the missing data

# %%
# How much of each variable is missing, and what would a complete-case
# analysis of the pair cost?

# %%
# Is the missingness related to anything you can observe? Try at least one
# grouping variable.

# %% [markdown]
# *Which mechanism — MCAR, MAR or MNAR — do these data look consistent with?*
# *Say what evidence you have, and say what you cannot rule out and why.*
#
# ---
#
# ## Question 3 — Inspect each variable
#
# Do this for **both** variables.

# %%
# Visual first: a histogram with a normal curve, and a Q-Q plot.

# %%
# Then the numbers.

# %% [markdown]
# *For each variable, write two or three sentences: what the plots show, what the*
# *shape statistics say, and what you conclude. Your conclusion must refer to the*
# *sample size.*
#
# ---
#
# ## Question 4 — Check the remaining assumptions

# %%
# Plot the two variables against each other.

# %% [markdown]
# *Look at the scatterplot and answer three questions:*
#
# 1. *Is the relationship approximately linear, or is it a curve?*
# 2. *Is the spread around the line roughly constant, or does it fan out?*
# 3. *Are there points that would clearly move the line on their own?*
#
# *Then: which correlation coefficient will you use, and why? Name the assumption*
# *that decided it.*
#
# ---
#
# ## Question 5 — Run the test

# %%
# Run the test you justified in Question 4. One test, not several.

# %%
# The effect size and the shared variance.

# %% [markdown]
# ---
#
# ## Question 6 — Report it

# %%
# Generate the report sentence. Do not type any numbers by hand.

# %% [markdown]
# *Then add two or three sentences of your own interpreting it: what does this*
# *mean about optimism and life satisfaction, in ordinary language, and what does*
# *it not mean?*
#
# ---
#
# ## Question 7 — A second pair, where the answer is different
#
# **Research question.** Is a respondent's age related to their level of negative
# affect?
#
# Variables: `age` and `tnegaff`.

# %%
# Work the same procedure: inspect, justify, test, report.

# %% [markdown]
# *This pair should lead you to a different decision somewhere in the procedure*
# *from the first pair. Say where, and why.*
#
# ---
#
# ## Question 8 — Sample size and significance

# %%
# Take the correlation you found in Question 7. Simulate what its p-value
# would have been at n = 30, 100, 500 and 2000, holding the strength of the
# relationship fixed.

# %% [markdown]
# *Write three sentences for a reader who thinks "significant" means "important".*
#
# ---
#
# ## Question 9 — Judgement
#
# No code. A report you are reviewing says:
#
# > "We ran Pearson, Spearman and Kendall correlations between optimism and life
# > satisfaction. Pearson gave the strongest result, so we report that one. The
# > Shapiro–Wilk test was significant for both variables, confirming that the data
# > are not normal, so a non-parametric test was required. Optimism therefore
# > causes higher life satisfaction."
#
# Identify **four** separate problems and rewrite the passage as it should have
# been written. One of the four is about the *procedure* rather than about any
# individual claim.
#
# ---
#
# ## Checklist before you finish
#
# - [ ] Hypotheses stated in words, with a tail direction chosen in advance.
# - [ ] Missing data quantified for the variables actually used, with a stated
#       view on the mechanism.
# - [ ] Each variable inspected visually **and** numerically, with the sample size
#       named in the conclusion.
# - [ ] Linearity and homoscedasticity checked on a scatterplot before any
#       correlation was computed.
# - [ ] Exactly one correlation coefficient reported, with the choice justified.
# - [ ] Effect size and shared variance reported alongside the p-value.
# - [ ] No number in your written report was typed by hand.
